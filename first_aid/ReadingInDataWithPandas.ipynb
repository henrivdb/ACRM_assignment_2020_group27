# %%
# import package
import pandas as pd

# %% [markdown]
# # Import Data

# %% [markdown]
# ## Facilities

# %%
# import facilities
facilities = pd.read_csv("./facilities.csv")

# %%
facilities.head(5)
# Out:
#                                        URI              name           street  \
# 0  http://irail.be/stations/NMBS/008734201             Arras              NaN
# 1  http://irail.be/stations/NMBS/008015345        Aachen Hbf              NaN
# 2  http://irail.be/stations/NMBS/008895000             Aalst  Stationsplein 9
# 3  http://irail.be/stations/NMBS/008895125  Aalst-Kerrebroek         Ledebaan
# 4  http://irail.be/stations/NMBS/008891140            Aalter  Stationsplein 2
#
#     zip    city  ticket_vending_machine  luggage_lockers  free_parking  taxi  \
# 0   NaN     NaN                     NaN              NaN           NaN   NaN
# 1   NaN     NaN                     NaN              NaN           NaN   NaN
# 2  9300   Aalst                     1.0              0.0           1.0   1.0
# 3  9300   Aalst                     0.0              0.0           1.0   0.0
# 4  9880  Aalter                     1.0              0.0           1.0   0.0
#
# ...

# %% [markdown]
# ## Satisfaction

# %%
# import data
satisfaction = pd.read_csv("./satisfaction.csv")

# %%
# check
satisfaction.describe()
# Out:
#        Unnamed: 0  Avg Satisfaction
# count  622.000000        580.000000
# mean   310.500000         47.452431
# std    179.700213         16.381599
# min      0.000000          2.030000
# 25%    155.250000         36.762500
# 50%    310.500000         48.135000
# 75%    465.750000         59.082500
# max    621.000000        100.000000

# %%
satisfaction.head(5)
# Out:
#    Unnamed: 0             station  Avg Satisfaction
# 0           0    COURCELLES-MOTTE              3.63
# 1           1                ROUX             13.58
# 2           2     RONET-FORMATION             55.84
# 3           3   SCHAARBEEK-D.O.P.               NaN
# 4           4  CHATELET-FORMATION             62.61
